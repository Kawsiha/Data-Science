# %% [markdown]
# Question 1:
#
# A retail store wants to identify customers who make frequent purchases. Given the dataset below, write a code to:
# 1.	Group customers by their IDs.
# 2.	Calculate the total number of purchases per customer.
# 3.	Identify the top 3 frequent customers.
# Dataset:
# data = {'Customer_ID': [101, 102, 103, 101, 104, 102, 101, 105, 102, 103],
#         'Purchase_Amount': [200, 150, 180, 220, 300, 200, 100, 400, 250, 300]}
#
# Expected Output:
#
# Total Purchases per Customer:
#    Customer_ID  Purchase_Amount
# 0          101              520
# 1          102              600
# 2          103              480
# 3          104              300
# 4          105              400
#
# Top 3 Frequent Customers:
#    Customer_ID  Purchase_Amount
# 1          102              600
# 0          101              520
# 2          103              480

# %%
import pandas as pd
data = {'Customer_ID': [101, 102, 103, 101, 104, 102, 101, 105, 102, 103], 'Purchase_Amount': [200, 150, 180, 220, 300, 200, 100, 400, 250, 300]}

dataset= pd.DataFrame(data)
dataset_freq =dataset.groupby('Customer_ID').size().reset_index(name='Purchase_Count')
print("CustomerList:",dataset)

# Sorting and getting top 3 customers
Sort=dataset_freq.sort_values(by='Purchase_Count',ascending=False).head(3)
print("Top 3 Customer:", Sort)
# Out:
# CustomerList:    Customer_ID  Purchase_Amount
# 0          101              200
# 1          102              150
# 2          103              180
# 3          101              220
# 4          104              300
# 5          102              200
# 6          101              100
# 7          105              400
# 8          102              250
# 9          103              300
# Top 3 Customer:    Customer_ID  Purchase_Count
# 0          101               3
# 1          102               3
# 2          103               2

# %% [markdown]
# Question 2:
#
# A company tracks the daily sales of a product over a month. You are tasked with identifying any abnormal sales data using the IQR (Interquartile Range) method.
# Dataset (Daily Sales in Units):
#
# data = {'Day': range(1, 31),
#         'Sales': [25, 30, 28, 45, 55, 60, 22, 80, 95, 120,
#                   33, 29, 27, 35, 40, 50, 85, 110, 105, 92,
#                   30, 34, 31, 33, 36, 42, 44, 48, 90, 200]}
#
# Tasks:
# 1. Calculate the Q1 (25th percentile) and Q3 (75th percentile).
# 2. Determine the IQR.
# 3. Identify the Lower Bound and Upper Bound.
# 4. Detect and display the outliers.
# 5. Replace the Outliers with the Median Value.
# Expected Output:
# Q1: 31.5, Q3: 83.75, IQR: 52.25
# Lower Bound: -46.875, Upper Bound: 162.125
# Outliers Detected:
#     Day  Sales
# 29   30    200
# Data After Replacing Outliers with Median:
#     Day  Sales
# 0     1   25.0
# 1     2   30.0
# 2     3   28.0
# 3     4   45.0
# 4     5   55.0
# 5     6   60.0
# 6     7   22.0
# 7     8   80.0
# 8     9   95.0
# 9    10  120.0
# 10   11   33.0
# 11   12   29.0
# 12   13   27.0
# 13   14   35.0
# 14   15   40.0
# 15   16   50.0
# 16   17   85.0
# 17   18  110.0
# 18   19  105.0
# 19   20   92.0
# 20   21   30.0
# 21   22   34.0
# 22   23   31.0
# 23   24   33.0
# 24   25   36.0
# 25   26   42.0
# 26   27   44.0
# 27   28   48.0
# 28   29   90.0
# 29   30   43.0

# %%
import numpy as np
data = {'Day': range(1, 31), 'Sales': [25, 30, 28, 45, 55, 60, 22, 80, 95, 120, 33, 29, 27, 35, 40, 50, 85, 110, 105, 92, 30, 34, 31, 33, 36, 42, 44, 48, 90, 200]}
dataset=pd.DataFrame(data)

Q1=dataset.describe()["Sales"]["25%"]
Q3=dataset.describe()["Sales"]["75%"]
IQR=Q3-Q1
Rule = 1.5 * IQR
Lower_Bound=Q1 - Rule
Upper_Bound=Q3 + Rule
print (f"Q1: {Q1}, Q3: {Q3}, IQR: {IQR}")
print (f"Lower_Bound: {Lower_Bound}, Upper_Bound: {Upper_Bound}")

outliers = dataset[(dataset['Sales'] < Lower_Bound) | (dataset['Sales'] > Upper_Bound)]
print (f"outliers: {outliers}")

median_value=dataset["Sales"].median()
dataset['Sales']= np.where((dataset["Sales"] < Lower_Bound) | (dataset["Sales"] > Upper_Bound), median_value, dataset["Sales"])
dataset
# Out:
# Q1: 31.5, Q3: 83.75, IQR: 52.25
# Lower_Bound: -46.875, Upper_Bound: 162.125
# outliers:     Day  Sales
# 29   30    200
#     Day  Sales
# 0     1   25.0
# 1     2   30.0
# 2     3   28.0
# 3     4   45.0
# 4     5   55.0
# 5     6   60.0
# 6     7   22.0
# 7     8   80.0
# 8     9   95.0
# 9    10  120.0
# 10   11   33.0
# 11   12   29.0
# 12   13   27.0
# 13   14   35.0
# 14   15   40.0
# 15   16   50.0
# 16   17   85.0
# 17   18  110.0
# 18   19  105.0
# 19   20   92.0
# 20   21   30.0
# 21   22   34.0
# 22   23   31.0
# 23   24   33.0
# 24   25   36.0
# 25   26   42.0
# 26   27   44.0
# 27   28   48.0
# 28   29   90.0
# 29   30   43.0

# %% [markdown]
# Question 3:
#
# A pharmaceutical company is testing the effectiveness of a new drug to reduce blood pressure. Two groups of patients were selected:
# Group 1 (Treatment): Received the drug
# Group 2 (Control): Received a placebo
# The company wants to check if there is a significant difference in the blood pressure levels between the two groups using an Independent T-Test.
# Dataset:
# data = {'Group': ['Treatment']*10 + ['Control']*10,
#         'Blood_Pressure': [120, 115, 118, 123, 122, 119, 124, 117, 116, 121,
#                             130, 135, 140, 138, 142, 136, 139, 134, 137, 141]}
# Tasks:
# 1.	Perform an Independent T-Test.
# 2.	State the null and alternative hypotheses.
# 3.	Calculate the p-value.
# 4.	Conclude whether the drug has a significant effect.
# Expected Output:
# T-Statistic: -11.870553692962726
# P-Value: 6.008066605173374e-10
# Reject the Null Hypothesis: The drug has a significant effect.

# %%
from scipy.stats import ttest_ind
import numpy as np
data = {'Group': ['Treatment']*10 + ['Control']*10,
        'Blood_Pressure': [120, 115, 118, 123, 122, 119, 124, 117, 116, 121,130, 135, 140, 138, 142, 136, 139, 134, 137, 141]}
dataset=pd.DataFrame(data)
Treatment=dataset[dataset['Group']=="Treatment"]["Blood_Pressure"]
Control=dataset[dataset['Group']=="Control"]["Blood_Pressure"]
t_stat, p_value = ttest_ind(Treatment, Control)
print(f"T-Statistic: {t_stat}, P_value: {p_value}")
if (p_value<=0.05):
    print("Reject the Null Hypothesis: The drug has a significant effect.")
else:
    print("Accept the Null Hypothesis: The drug has no significant effect.")
# Out:
# T-Statistic: -11.870553692962726, P_value: 6.008066605173374e-10
# Reject the Null Hypothesis: The drug has a significant effect.

# %% [markdown]
# Question 4:
#
# GlobalMart is a large retailer conducting advertisement campaigns in different regions. The company spends money on two types of advertisements: TV Ads and Social Media Ads
# They want to analyze how these ads influence their sales.
# Your task is to calculate the Covariance and Correlation to determine which type of ad has a stronger impact on sales.
# Tasks :
# 1.	Calculate the Covariance between ad budgets and sales to measure the direction of the relationship.
# 2.	Calculate the Correlation to measure the strength of the relationship.
# 3.	Determine which type of ad is more effective for increasing sales.
#
#
# Expected Output:
# Covariance (TV vs Sales): 3625.0
# Covariance (Social Media vs Sales): 3225.0
# Correlation (TV vs Sales): 0.9958640886279954
# Correlation (Social Media vs Sales): 0.9724846021568381
# TV Ads have a stronger impact on Sales.

# %%
import pandas as pd

data = {'Region': ['North', 'South', 'East', 'West', 'Central'],'TV_Ad_Budget': [200, 300, 400, 500, 600],'Social_Media_Budget': [150, 250, 300, 450, 500],'Sales': [20, 35, 50, 60, 80]}

dataset=pd.DataFrame(data)
print("Covariance (TV vs Sales):", dataset["TV_Ad_Budget"].cov(dataset["Sales"]))
print("Covariance (Social Media vs Sales):", dataset["Social_Media_Budget"].cov(dataset["Sales"]))
Cor_tv = dataset["TV_Ad_Budget"].corr(dataset["Sales"])
cor_sm = dataset["Social_Media_Budget"].corr(dataset["Sales"])
print("Correlation (TV vs Sales):", Cor_tv)
print("Correlation (Social Media vs Sales):", cor_sm)
if(Cor_tv > cor_sm):
    print("TV Ads have a stronger impact on Sales.")
else:
    print("SocialMedia Ads have a stronger impact on Sales.")
# Out:
# Covariance (TV vs Sales): 3625.0
# Covariance (Social Media vs Sales): 3225.0
# Correlation (TV vs Sales): 0.9958640886279954
# Correlation (Social Media vs Sales): 0.9724846021568381
# TV Ads have a stronger impact on Sales.

# %% [markdown]
# Question 5:
#
# A company tracks the delivery time (in minutes) for its online orders. You are given the delivery times for 50 orders.
# ●	Calculate the mean and standard deviation of the delivery times.
# ●	Plot the Probability Density Function (PDF) to visualize the distribution.
# Dataset (Delivery Times in Minutes):
#
# [25, 30, 28, 45, 55, 60, 22, 80, 95, 120, 33, 29, 27, 35, 40, 50, 85, 110, 105, 92, 30, 34, 31, 33, 36, 42, 44, 48, 90, 200, 20, 25, 27, 32, 38, 41, 47, 58, 62, 77, 80, 84, 90, 110, 123, 145, 150, 160]
# You can try implementing this using libraries like numpy, matplotlib, and scipy
# Expected Output:
#
# Mean Delivery Time: 65.0625
# Standard Deviation of Delivery Time: 41.718504212759115

# %%
data = [25, 30, 28, 45, 55, 60, 22, 80, 95, 120, 33, 29, 27, 35, 40, 50, 85, 110, 105, 92, 30, 34, 31, 33, 36, 42, 44, 48, 90, 200, 20, 25, 27, 32, 38, 41, 47, 58, 62, 77, 80, 84, 90, 110, 123, 145, 150, 160]
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

Mean = np.mean(data)
Stand_dev = np.std(data)
print(f"Mean Delivery Time: {Mean}, Standard Deviation of Delivery Time: {Stand_dev}")


x = np.linspace(min(data), max(data),100)
pdf_values = norm.pdf(x, Mean,Stand_dev)
plt.plot(x, pdf_values, color="Red")
plt.xlabel("x")
plt.ylabel("PDF")
plt.legend()
plt.show()
# Out:
# Mean Delivery Time: 65.0625, Standard Deviation of Delivery Time: 41.718504212759115
# C:\Users\keert\AppData\Local\Temp\ipykernel_27772\1687863415.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
